# %%
import os
import pandas as pd   #holds data
import numpy as np    #numerical calc package
import seaborn as sns #pretty plotting
import matplotlib.pyplot as plt # plotting library
from scipy.stats import norm
import warnings
warnings.filterwarnings('ignore')

# plotting config
sns.set(style='white', rc={'figure.figsize':(20,10)})



# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/ngala/Downloads/insurance.csv")

# %%
#1learning data

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
#check data shape(rows and columns)

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
#2cleaning data

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.set(font_scale=1)
barplot1 = data['sex'].value_counts(ascending=False).plot(kind='bar', figsize=(4,7), color='cyan', edgecolor = 'black')
plt.xlabel("Gender", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title('No. of Males and Females in the Insurance Dataset', y=1.02)
plt.show()

# %%
data['sex'].value_counts(ascending=True) #counts number of female and male
# Out:
# female    662
# male      676
# Name: sex, dtype: int64

# %% [markdown]
# the number of males is 676 while
#               females is  662

# %%
sns.set(font_scale=1)
barplot2 = data['smoker'].value_counts(ascending=False).plot(kind='bar', figsize=(4,7), color='red', edgecolor = 'black')
plt.xlabel("Smoker", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title('No. of Smokers in the Insurance Dataset', y=1.02)
plt.show()

# %% [markdown]
# Non smokers are more than the smokers

# %%
data['smoker'].value_counts(ascending=True)
# Out:
# yes     274
# no     1064
# Name: smoker, dtype: int64

# %%
sns.set(font_scale=1)
barplot3 = data['region'].value_counts(ascending=False).plot(kind='bar', figsize=(4,7), color='blue', edgecolor = 'black')
plt.xlabel("Region", labelpad=14)
plt.ylabel("Count", labelpad=14)
plt.title('No. of People per Region in the Insurance Dataset', y=1.02)
plt.show()

# %%
data['region'].value_counts(ascending=True)
# Out:
# northeast    324
# southwest    325
# northwest    325
# southeast    364
# Name: region, dtype: int64

# %%
sns.set(font_scale=1)
barplot4 = data['children'].value_counts(ascending=False).plot(kind='bar', figsize=(4,7), color='yellow', edgecolor = 'black')
plt.xlabel("No. of Children", labelpad=14)
plt.ylabel("No. of People", labelpad=14)
plt.title('No. of People with Children in the Insurance Dataset', y=1.02)
plt.show()

# %% [markdown]
# The number of people decrases as the number of children increase

# %%
data['children'].value_counts(ascending=False)
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
data['charges'].hist(bins='auto', alpha=0.9)
plt.title('Histogram of Charges')
plt.ylabel('Counts')
plt.grid(axis='y', alpha=0.75)
plt.show()

data['age'].hist(bins='auto', alpha=0.9)
plt.title('Histogram of Age')
plt.ylabel('Counts')
plt.grid(axis='y', alpha=0.75)
plt.show()

data['bmi'].hist(bins='auto', alpha=0.9)
plt.title('Histogram of BMI')
plt.ylabel('Counts')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
#  Histogram of charges is positively skewed, where most charges are aorund the 0–15000 range.

# %% [markdown]
# Given the knowledge in exploratory data analysis through pandas and matplotlib, I was able to understand the cleaned insurance dataset and show visualizations for pre-data analysis.
